# %%
import requests, threading, time, datetime
from datetime import timedelta
from IPython import display
date = datetime.date.today()
timer = int(round(time.time()))
print(date) 
x = 1

while(x == 1):
    time.sleep(5)
    api_key = 'hR3Vbtn55QRRwXY0F24wYpEWYrEHmiscforVZBJO'
    url = f'https://api.nasa.gov/planetary/apod?api_key={api_key}&date={date}'
    response = requests.get(url)   
    image_url = response.json()['url']
    if(image_url.find("youtube") != -1):
        continue
    if(int(round(time.time())) > timer):
        date -= timedelta(days = 1)
        timer = int(round(time.time())) + 2
        display.clear_output()
        display.display(display.Image(image_url))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-dae403be6edc> in <module>
#       8
#       9 while(x == 1):
# ---> 10     time.sleep(5)
#      11     api_key = 'hR3Vbtn55QRRwXY0F24wYpEWYrEHmiscforVZBJO'
#      12     url = f'https://api.nasa.gov/planetary/apod?api_key={api_key}&date={date}'
#
# KeyboardInterrupt:
